# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option.float_format = '{:.2f}.format'

# %%
df = pd.read_csv('dataframe_sisu.csv')

# %%
df.head(5)
# Out:
#   data_nascimento sexo                            modalidade_concorrencia  \
# 0      1996-07-03    F  egressos de escolas públicas da rede federal. ...
# 1      2003-12-20    M                                 Ampla concorrência
# 2      2001-08-17    F  Candidatos que. independentemente da renda (ar...
# 3      2003-02-07    M                                 Ampla concorrência
# 4      2004-05-19    M                                 Ampla concorrência
#
#    id_municipio_candidato uf_candidato  nota_linguagens  \
# 0                 2927408           BA            634.8
# 1                 3304557           RJ            596.0
# 2                 2925303           BA            592.5
# 3                 1501402           PA            635.8
# 4                 2211001           PI            641.5
#
#    nota_ciencias_humanas  nota_ciencias_natureza  nota_matematica  \
# 0                  677.1                   672.9            648.9
# 1                  689.9                   652.5            762.3
# 2                  603.9                   641.2            697.9
# 3                  714.8                   693.3            803.2
# 4                  679.6                   682.2            826.3
#
#    nota_redacao  nota_corte    nota                nome_curso universidade  \
# 0         880.0      677.24  702.74  ENGENHARIA DA COMPUTAÇÃO          UPE
# 1         920.0      721.92  724.14  ENGENHARIA DA COMPUTAÇÃO          UPE
# 2         920.0      638.80  711.04  ENGENHARIA DA COMPUTAÇÃO         UFPE
# 3         900.0      770.26  775.00  ENGENHARIA DA COMPUTAÇÃO         UFPE
# 4         780.0      721.92  721.92  ENGENHARIA DA COMPUTAÇÃO          UPE
#
#                                   campus status_matricula
# 0                     ESCOLA POLITÉCNICA        Efetivada
# 1                     ESCOLA POLITÉCNICA        Efetivada
# 2  Campus Universitário Cidade do Recife        Efetivada
# 3  Campus Universitário Cidade do Recife        Efetivada
# 4                     ESCOLA POLITÉCNICA        Efetivada
